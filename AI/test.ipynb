# %%
import cv2
import mediapipe as mp

mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh

cap = cv2.VideoCapture(1)

with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # Make Detections
        results = holistic.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # 1. Face landmarks
        if results.face_landmarks:
            mp_drawing.draw_landmarks(
                image,
                results.face_landmarks,
                mp_face_mesh.FACEMESH_TESSELATION,
                mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
            )

        # 2. Right hand
        if results.right_hand_landmarks:
            mp_drawing.draw_landmarks(
                image,
                results.right_hand_landmarks,
                mp_holistic.HAND_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
            )

        # 3. Left hand
        if results.left_hand_landmarks:
            mp_drawing.draw_landmarks(
                image,
                results.left_hand_landmarks,
                mp_holistic.HAND_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
            )

        # 4. Pose
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_holistic.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
            )

        cv2.imshow('Raw Webcam Feed', image)

        # Exit when pressing q
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
results.pose_landmarks
# Out:
# landmark {
#   x: 0.5147652
#   y: 0.14409445
#   z: -0.90637493
#   visibility: 0.99995404
# }
# landmark {
#   x: 0.5690483
#   y: 0.060319785
#   z: -0.85677254
#   visibility: 0.9998888
# }
# landmark {
#   x: 0.6020826
#   y: 0.062065873
#   z: -0.8566617
#   visibility: 0.9998801
# }
# landmark {
#   x: 0.6305913
#   y: 0.06360208
#   z: -0.8567499
#   visibility: 0.99986327
# }
# landmark {
#   x: 0.4727729
#   y: 0.050716393
#   z: -0.86603516
#   visibility: 0.9999074
# }
# landmark {
#   x: 0.43641704
#   y: 0.048305117
#   z: -0.86584675
#   visibility: 0.999908
# }
# landmark {
#   x: 0.40630078
#   y: 0.04826367
#   z: -0.86633044
#   visibility: 0.99990946
# }
# landmark {
#   x: 0.6680206
#   y: 0.09446389
#   z: -0.52307165
#   visibility: 0.9998483
# }
# landmark {
#   x: 0.35316822
#   y: 0.08029975
#   z: -0.54783857
#   visibility: 0.99994016
# }
# landmark {
#   x: 0.55586
#   y: 0.23439308
#   z: -0.7866733
#   visibility: 0.999945
# }
# landmark {
#   x: 0.4582664
#   y: 0.23069693
#   z: -0.7914559
#   visibility: 0.9999681
# }
# landmark {
#   x: 0.7651655
#   y: 0.5173087
#   z: -0.3179121
#   visibility: 0.9986751
# }
# landmark {
#   x: 0.1877524
#   y: 0.49905044
#   z: -0.425982
#   visibility: 0.9991833
# }
# landmark {
#   x: 0.86455363
#   y: 0.91155547
#   z: -0.32953674
#   visibility: 0.3715654
# }
# landmark {
#   x: 0.07642156
#   y: 0.9448618
#   z: -0.3086842
#   visibility: 0.5112349
# }
# landmark {
#   x: 0.8989255
#   y: 1.2715343
#   z: -0.7699027
#   visibility: 0.22603089
# }
# landmark {
#   x: 0.047178563
#   y: 1.4353551
#   z: -0.72681606
#   visibility: 0.3401003
# }
# landmark {
#   x: 0.92500496
#   y: 1.3647941
#   z: -0.8911479
#   visibility: 0.2608543
# }
# landmark {
#   x: 0.014083212
#   y: 1.5710787
#   z: -0.8406435
#   visibility: 0.36531195
# }
# landmark {
#   x: 0.8838048
#   y: 1.3100772
#   z: -0.9399675
#   visibility: 0.32397172
# }
# landmark {
#   x: 0.072008684
#   y: 1.5336072
#   z: -0.94235325
#   visibility: 0.45339003
# }
# landmark {
#   x: 0.856565
#   y: 1.2786378
#   z: -0.80244464
#   visibility: 0.33621395
# }
# landmark {
#   x: 0.10258806
#   y: 1.4836673
#   z: -0.78554416
#   visibility: 0.46910757
# }
# landmark {
#   x: 0.63474005
#   y: 1.428864
#   z: -0.010192508
#   visibility: 0.0069524804
# }
# landmark {
#   x: 0.27200216
#   y: 1.4349086
#   z: 0.016548244
#   visibility: 0.0068615857
# }
# landmark {
#   x: 0.61248195
#   y: 2.158241
#   z: 0.011402158
#   visibility: 0.0013663383
# }
# landmark {
#   x: 0.28726736
#   y: 2.161138
#   z: -0.057660036
#   visibility: 0.00034483915
# }
# landmark {
#   x: 0.58174264
#   y: 2.7917395
#   z: 0.61004245
#   visibility: 7.060472e-05
# }
# landmark {
#   x: 0.27511832
#   y: 2.7774897
#   z: 0.34168884
#   visibility: 9.464363e-06
# }
# landmark {
#   x: 0.58320016
#   y: 2.8923812
#   z: 0.6307885
#   visibility: 7.738601e-05
# }
# landmark {
#   x: 0.26934105
#   y: 2.8823526
#   z: 0.35763755
#   visibility: 1.7258459e-05
# }
# landmark {
#   x: 0.51531506
#   y: 3.0342698
#   z: 0.055855833
#   visibility: 8.004521e-05
# }
# landmark {
#   x: 0.31971473
#   y: 3.0038657
#   z: -0.30135202
#   visibility: 4.655991e-05
# }

# %%
import requests

url = "https://i.imgur.com/AzKNp7A.png"
response = requests.get(url)

print("Status code:", response.status_code)
print("Content-Type:", response.headers.get("Content-Type"))
# Out:
# Status code: 429
# Content-Type: None

# %% [markdown]
# # 2. Capture Landmarks & Export to CSV

# %%
from PIL import Image
import requests
from io import BytesIO

url = "https://i.imgur.com/AzKNp7A.png"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print("Status:", response.status_code)
print("Type:", response.headers.get("Content-Type"))

image = Image.open(BytesIO(response.content))
# Out:
# Status: 200
# Type: image/png

# %%
image.show()

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coords
# Out:
# 501

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "Better"

# %%
import cv2
import mediapipe as mp

mp_drawing = mp.solutions.drawing_utils
mp_holistic = mp.solutions.holistic
mp_face_mesh = mp.solutions.face_mesh

cap = cv2.VideoCapture(1)

with mp_holistic.Holistic(
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # Make Detections
        results = holistic.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # 1. Face landmarks
        if results.face_landmarks:
            mp_drawing.draw_landmarks(
                image,
                results.face_landmarks,
                mp_face_mesh.FACEMESH_TESSELATION,
                mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
            )

        # 2. Right hand
        if results.right_hand_landmarks:
            mp_drawing.draw_landmarks(
                image,
                results.right_hand_landmarks,
                mp_holistic.HAND_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
            )

        # 3. Left hand
        if results.left_hand_landmarks:
            mp_drawing.draw_landmarks(
                image,
                results.left_hand_landmarks,
                mp_holistic.HAND_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
            )

        # 4. Pose
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_holistic.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
            )
            
             # Export coordinates
        try:
          
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
           
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass

        cv2.imshow('Raw Webcam Feed', image)

        # Exit when pressing q
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 3. Train Custom Model Using Scikit Learn

# %% [markdown]
# ## 3.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 684 -0.637396  0.999418  0.555014  ...  0.006671   0.0  0.570413  0.100347
# 685 -0.583581  0.999370  0.555487  ...  0.006072   0.0  0.569201  0.101640
# 686 -0.589806  0.999336  0.556327  ...  0.006109   0.0  0.570098  0.102024
# 687 -0.594909  0.999303  0.556764  ...  0.005835   0.0  0.571323  0.101448
# 688 -0.589158  0.999300  0.556850  ...  0.006928   0.0  0.570622  0.102035
#
#          z500  v500      x501      y501      z501  v501
# 684  0.018645   0.0  0.573841  0.096327  0.019239   0.0
# 685  0.017528   0.0  0.572763  0.097189  0.018100   0.0
# 686  0.017494   0.0  0.573580  0.098005  0.018014   0.0
# 687  0.017199   0.0  0.574848  0.097143  0.017744   0.0
# 688  0.018718   0.0  0.574138  0.097735  0.019343   0.0
#
# [5 rows x 2005 columns]

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=1234)

# %%
y_test
# Out:
# 1265          Bored
# 1048        Anxiety
# 880     Appropriate
# 824     Appropriate
# 370      Discomfort
#            ...
# 878     Appropriate
# 899     Appropriate
# 1084          Bored
# 1287          Bored
# 1241          Bored
# Name: class, Length: 789, dtype: str

# %% [markdown]
# ## 3.2 Train Machine Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Bored', 'Anxiety', 'Appropriate', 'Appropriate', 'Discomfort',
#        'Bored', 'Appropriate', 'Discomfort', 'Discomfort', 'Bored',
#        'Discomfort', 'Discomfort', 'Anxiety', 'Better', 'Appropriate',
#        'Discomfort', 'Bored', 'Better', 'Bored', 'Discomfort', 'Anxiety',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Appropriate', 'Bored', 'Discomfort', 'Better',
#        'Discomfort', 'Anxiety', 'Anxiety', 'Discomfort', 'Discomfort',
#        'Better', 'Discomfort', 'Discomfort', 'Appropriate', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Bored', 'Appropriate', 'Anxiety',
#        'Discomfort', 'Appropriate', 'Discomfort', 'Anxiety', 'Bored',
#        'Appropriate', 'Discomfort', 'Better', 'Better', 'Discomfort',
#        'Better', 'Better', 'Bored', 'Appropriate', 'Anxiety',
#        'Discomfort', 'Appropriate', 'Discomfort', 'Bored', 'Discomfort',
#        'Bored', 'Bored', 'Appropriate', 'Discomfort', 'Anxiety', 'Bored',
#        'Discomfort', 'Appropriate', 'Better', 'Appropriate', 'Discomfort',
#        'Bored', 'Discomfort', 'Bored', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Appropriate', 'Bored', 'Discomfort',
#        'Bored', 'Bored', 'Bored', 'Discomfort', 'Discomfort', 'Better',
#        'Bored', 'Discomfort', 'Discomfort', 'Discomfort', 'Bored',
#        'Discomfort', 'Bored', 'Bored', 'Bored', 'Discomfort',
#        'Appropriate', 'Appropriate', 'Discomfort', 'Appropriate', 'Bored',
#        'Discomfort', 'Bored', 'Anxiety', 'Appropriate', 'Discomfort',
#        'Anxiety', 'Bored', 'Discomfort', 'Discomfort', 'Better',
#        'Discomfort', 'Better', 'Appropriate', 'Appropriate',
#        'Appropriate', 'Appropriate', 'Appropriate', 'Bored',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Bored', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Bored', 'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Anxiety', 'Discomfort', 'Discomfort', 'Anxiety', 'Bored', 'Bored',
#        'Better', 'Appropriate', 'Bored', 'Discomfort', 'Bored',
#        'Appropriate', 'Discomfort', 'Better', 'Discomfort', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort', 'Anxiety',
#        'Discomfort', 'Better', 'Discomfort', 'Anxiety', 'Anxiety',
#        'Appropriate', 'Discomfort', 'Better', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Discomfort', 'Better', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Appropriate', 'Bored', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Bored', 'Appropriate',
#        'Discomfort', 'Better', 'Anxiety', 'Appropriate', 'Discomfort',
#        'Appropriate', 'Appropriate', 'Better', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Appropriate', 'Discomfort', 'Better',
#        'Discomfort', 'Anxiety', 'Discomfort', 'Bored', 'Discomfort',
#        'Discomfort', 'Appropriate', 'Better', 'Bored', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Bored', 'Bored', 'Discomfort',
#        'Appropriate', 'Bored', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Bored', 'Bored', 'Bored', 'Discomfort', 'Discomfort', 'Bored',
#        'Anxiety', 'Appropriate', 'Discomfort', 'Discomfort', 'Better',
#        'Bored', 'Appropriate', 'Appropriate', 'Discomfort', 'Better',
#        'Discomfort', 'Appropriate', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Bored', 'Discomfort', 'Appropriate', 'Bored',
#        'Discomfort', 'Bored', 'Anxiety', 'Anxiety', 'Anxiety',
#        'Discomfort', 'Bored', 'Better', 'Bored', 'Anxiety', 'Bored',
#        'Discomfort', 'Discomfort', 'Better', 'Bored', 'Discomfort',
#        'Anxiety', 'Discomfort', 'Anxiety', 'Bored', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Better', 'Appropriate', 'Anxiety',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Bored', 'Discomfort',
#        'Better', 'Bored', 'Appropriate', 'Discomfort', 'Appropriate',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Bored', 'Discomfort',
#        'Anxiety', 'Discomfort', 'Better', 'Bored', 'Discomfort',
#        'Appropriate', 'Bored', 'Discomfort', 'Bored', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Appropriate', 'Appropriate', 'Discomfort', 'Bored',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Appropriate', 'Appropriate', 'Anxiety',
#        'Discomfort', 'Appropriate', 'Anxiety', 'Discomfort', 'Discomfort',
#        'Anxiety', 'Bored', 'Appropriate', 'Bored', 'Bored', 'Discomfort',
#        'Appropriate', 'Better', 'Discomfort', 'Discomfort', 'Bored',
#        'Discomfort', 'Discomfort', 'Bored', 'Better', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Anxiety', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Bored', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Better', 'Bored', 'Appropriate', 'Discomfort',
#        'Bored', 'Discomfort', 'Anxiety', 'Bored', 'Discomfort', 'Bored',
#        'Discomfort', 'Bored', 'Bored', 'Bored', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Anxiety', 'Better',
#        'Discomfort', 'Better', 'Discomfort', 'Anxiety', 'Discomfort',
#        'Bored', 'Discomfort', 'Discomfort', 'Bored', 'Bored',
#        'Discomfort', 'Discomfort', 'Appropriate', 'Anxiety', 'Bored',
#        'Discomfort', 'Bored', 'Discomfort', 'Discomfort', 'Bored',
#        'Bored', 'Bored', 'Appropriate', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Bored', 'Anxiety',
#        'Discomfort', 'Anxiety', 'Anxiety', 'Appropriate', 'Bored',
#        'Discomfort', 'Better', 'Discomfort', 'Better', 'Bored', 'Bored',
#        'Discomfort', 'Bored', 'Better', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Appropriate', 'Anxiety', 'Bored',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Anxiety', 'Discomfort',
#        'Discomfort', 'Better', 'Discomfort', 'Bored', 'Discomfort',
#        'Appropriate', 'Bored', 'Bored', 'Discomfort', 'Anxiety', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Anxiety', 'Appropriate', 'Bored',
#        'Discomfort', 'Appropriate', 'Anxiety', 'Bored', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Anxiety', 'Bored', 'Discomfort',
#        'Discomfort', 'Bored', 'Discomfort', 'Bored', 'Discomfort',
#        'Better', 'Discomfort', 'Better', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Appropriate', 'Better', 'Bored', 'Bored',
#        'Discomfort', 'Discomfort', 'Bored', 'Better', 'Bored', 'Bored',
#        'Discomfort', 'Anxiety', 'Anxiety', 'Discomfort', 'Discomfort',
#        'Bored', 'Appropriate', 'Better', 'Discomfort', 'Appropriate',
#        'Better', 'Bored', 'Bored', 'Appropriate', 'Anxiety', 'Bored',
#        'Discomfort', 'Better', 'Discomfort', 'Appropriate', 'Discomfort',
#        'Bored', 'Appropriate', 'Discomfort', 'Discomfort', 'Anxiety',
#        'Bored', 'Discomfort', 'Bored', 'Bored', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Discomfort', 'Better',
#        'Bored', 'Discomfort', 'Bored', 'Discomfort', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Bored', 'Appropriate', 'Bored',
#        'Discomfort', 'Discomfort', 'Bored', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Better', 'Appropriate', 'Appropriate',
#        'Bored', 'Appropriate', 'Better', 'Appropriate', 'Anxiety',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Discomfort', 'Anxiety', 'Discomfort', 'Better',
#        'Bored', 'Discomfort', 'Discomfort', 'Appropriate', 'Bored',
#        'Discomfort', 'Bored', 'Appropriate', 'Discomfort', 'Discomfort',
#        'Bored', 'Better', 'Appropriate', 'Discomfort', 'Bored',
#        'Appropriate', 'Anxiety', 'Appropriate', 'Bored', 'Discomfort',
#        'Discomfort', 'Bored', 'Discomfort', 'Better', 'Appropriate',
#        'Anxiety', 'Bored', 'Anxiety', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Better', 'Discomfort', 'Better', 'Better',
#        'Anxiety', 'Discomfort', 'Discomfort', 'Better', 'Bored', 'Better',
#        'Discomfort', 'Discomfort', 'Appropriate', 'Bored', 'Discomfort',
#        'Better', 'Discomfort', 'Discomfort', 'Bored', 'Discomfort',
#        'Appropriate', 'Bored', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Bored', 'Bored', 'Discomfort', 'Discomfort',
#        'Bored', 'Discomfort', 'Anxiety', 'Bored', 'Discomfort', 'Better',
#        'Bored', 'Discomfort', 'Better', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Bored', 'Appropriate', 'Better',
#        'Discomfort', 'Appropriate', 'Discomfort', 'Better', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Discomfort', 'Better', 'Discomfort',
#        'Bored', 'Better', 'Appropriate', 'Bored', 'Discomfort', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Better', 'Bored',
#        'Discomfort', 'Appropriate', 'Bored', 'Better', 'Anxiety',
#        'Discomfort', 'Bored', 'Better', 'Better', 'Bored', 'Appropriate',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Anxiety', 'Discomfort',
#        'Bored', 'Bored', 'Discomfort', 'Bored', 'Appropriate', 'Anxiety',
#        'Bored', 'Better', 'Better', 'Anxiety', 'Bored', 'Discomfort',
#        'Bored', 'Discomfort', 'Discomfort', 'Bored', 'Discomfort',
#        'Better', 'Appropriate', 'Discomfort', 'Better', 'Bored', 'Better',
#        'Bored', 'Discomfort', 'Appropriate', 'Bored', 'Bored',
#        'Appropriate', 'Better', 'Better', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Better', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Better', 'Better', 'Discomfort',
#        'Discomfort', 'Better', 'Appropriate', 'Anxiety', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Appropriate',
#        'Appropriate', 'Appropriate', 'Bored', 'Bored', 'Bored', 'Better',
#        'Anxiety', 'Discomfort', 'Appropriate', 'Anxiety', 'Appropriate',
#        'Better', 'Discomfort', 'Appropriate', 'Better', 'Discomfort',
#        'Anxiety', 'Anxiety', 'Discomfort', 'Better', 'Discomfort',
#        'Anxiety', 'Bored', 'Anxiety', 'Bored', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Better', 'Discomfort', 'Discomfort', 'Bored',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Bored', 'Bored',
#        'Discomfort', 'Appropriate', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Anxiety', 'Discomfort', 'Appropriate',
#        'Appropriate', 'Discomfort', 'Appropriate', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Appropriate',
#        'Appropriate', 'Bored', 'Bored', 'Bored'], dtype='<U11')

# %% [markdown]
# ## 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, confusion_matrix, ConfusionMatrixDisplay # Accuracy metrics 
import pickle 
import matplotlib.pyplot as plt

# %%
algo_names = []
accuracy_values = []
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    acc = accuracy_score(y_test, yhat)
    
    algo_names.append(algo)
    accuracy_values.append(acc)

    print(algo, acc)

# สร้างกราฟ
plt.figure(figsize=(8,5))
plt.bar(algo_names, accuracy_values)
plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.title("Accuracy Comparison")
plt.ylim(0,1)
plt.show()
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 0.9974651457541192

# %%
algo_names = []
recall_values = []

for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    recall = recall_score(y_test, yhat, average='macro')
    
    algo_names.append(algo)
    recall_values.append(recall)

    print(algo, recall)

# สร้างกราฟ
plt.figure(figsize=(8,5))
plt.bar(algo_names, recall_values)

plt.xlabel("Algorithm")
plt.ylabel("Recall Score")
plt.title("Recall Comparison")
plt.ylim(0,1)

plt.show()
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 0.9945205479452055

# %%
algo_names = []
f1_values = []

for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    f1 = f1_score(y_test, yhat, average='weighted')
    
    algo_names.append(algo)
    f1_values.append(f1)

    print(algo, f1)

# สร้างกราฟ
plt.figure(figsize=(8,5))
plt.bar(algo_names, f1_values)

plt.xlabel("Algorithm")
plt.ylabel("F1 Score")
plt.title("F1 Score Comparison")
plt.ylim(0,1)

plt.show()
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 0.9974512056838042

# %%
algo_names = []
precision_values = []

for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    precision = precision_score(y_test, yhat, average='weighted')
    
    algo_names.append(algo)
    precision_values.append(precision)

    print(algo, precision)

# สร้างกราฟ
plt.figure(figsize=(8,5))
plt.bar(algo_names, precision_values)

plt.xlabel("Algorithm")
plt.ylabel("Precision Score")
plt.title("Precision Score Comparison")
plt.ylim(0,1)

plt.show()
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 0.9974797558650463

# %%
for algo, model in fit_models.items():
    
    yhat = model.predict(X_test)
    cm = confusion_matrix(y_test, yhat)
    plt.figure(figsize=(10,10))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot(cmap=plt.cm.Blues) 
    plt.title(f"Confusion Matrix - {algo}")
    plt.xticks(rotation=45) 
    plt.show()

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Bored', 'Anxiety', 'Appropriate', 'Appropriate', 'Discomfort',
#        'Bored', 'Appropriate', 'Discomfort', 'Discomfort', 'Bored',
#        'Discomfort', 'Discomfort', 'Anxiety', 'Better', 'Appropriate',
#        'Discomfort', 'Bored', 'Better', 'Bored', 'Discomfort', 'Anxiety',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Appropriate', 'Bored', 'Discomfort', 'Better',
#        'Discomfort', 'Anxiety', 'Anxiety', 'Discomfort', 'Discomfort',
#        'Better', 'Discomfort', 'Discomfort', 'Appropriate', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Bored', 'Appropriate', 'Anxiety',
#        'Discomfort', 'Appropriate', 'Discomfort', 'Anxiety', 'Bored',
#        'Appropriate', 'Discomfort', 'Better', 'Better', 'Discomfort',
#        'Better', 'Better', 'Bored', 'Appropriate', 'Anxiety',
#        'Discomfort', 'Appropriate', 'Discomfort', 'Bored', 'Discomfort',
#        'Bored', 'Bored', 'Appropriate', 'Discomfort', 'Anxiety', 'Bored',
#        'Discomfort', 'Appropriate', 'Better', 'Appropriate', 'Discomfort',
#        'Bored', 'Discomfort', 'Bored', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Appropriate', 'Bored', 'Discomfort',
#        'Bored', 'Bored', 'Bored', 'Discomfort', 'Discomfort', 'Better',
#        'Bored', 'Discomfort', 'Discomfort', 'Discomfort', 'Bored',
#        'Discomfort', 'Bored', 'Bored', 'Bored', 'Discomfort',
#        'Appropriate', 'Appropriate', 'Discomfort', 'Appropriate', 'Bored',
#        'Discomfort', 'Bored', 'Anxiety', 'Appropriate', 'Discomfort',
#        'Anxiety', 'Bored', 'Discomfort', 'Discomfort', 'Better',
#        'Discomfort', 'Better', 'Appropriate', 'Appropriate',
#        'Appropriate', 'Appropriate', 'Appropriate', 'Bored',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Bored', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Bored', 'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Anxiety', 'Discomfort', 'Discomfort', 'Anxiety', 'Bored', 'Bored',
#        'Better', 'Appropriate', 'Bored', 'Discomfort', 'Bored',
#        'Appropriate', 'Discomfort', 'Better', 'Discomfort', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort', 'Anxiety',
#        'Discomfort', 'Better', 'Discomfort', 'Anxiety', 'Anxiety',
#        'Appropriate', 'Discomfort', 'Better', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Discomfort', 'Better', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Appropriate', 'Bored', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Bored', 'Appropriate',
#        'Discomfort', 'Better', 'Anxiety', 'Appropriate', 'Discomfort',
#        'Appropriate', 'Appropriate', 'Better', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Appropriate', 'Discomfort', 'Better',
#        'Discomfort', 'Anxiety', 'Discomfort', 'Bored', 'Discomfort',
#        'Discomfort', 'Appropriate', 'Better', 'Bored', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Bored', 'Bored', 'Discomfort',
#        'Appropriate', 'Bored', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Bored', 'Bored', 'Bored', 'Discomfort', 'Discomfort', 'Bored',
#        'Anxiety', 'Appropriate', 'Discomfort', 'Discomfort', 'Better',
#        'Bored', 'Appropriate', 'Appropriate', 'Discomfort', 'Better',
#        'Discomfort', 'Appropriate', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Bored', 'Discomfort', 'Appropriate', 'Bored',
#        'Discomfort', 'Bored', 'Anxiety', 'Anxiety', 'Anxiety',
#        'Discomfort', 'Bored', 'Better', 'Bored', 'Anxiety', 'Bored',
#        'Discomfort', 'Discomfort', 'Better', 'Bored', 'Discomfort',
#        'Anxiety', 'Discomfort', 'Anxiety', 'Bored', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Better', 'Appropriate', 'Anxiety',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Bored', 'Discomfort',
#        'Better', 'Bored', 'Appropriate', 'Discomfort', 'Appropriate',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Bored', 'Discomfort',
#        'Anxiety', 'Discomfort', 'Better', 'Bored', 'Discomfort',
#        'Appropriate', 'Bored', 'Discomfort', 'Bored', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Appropriate', 'Appropriate', 'Discomfort', 'Bored',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Appropriate', 'Appropriate', 'Anxiety',
#        'Discomfort', 'Appropriate', 'Anxiety', 'Discomfort', 'Discomfort',
#        'Anxiety', 'Bored', 'Appropriate', 'Bored', 'Bored', 'Discomfort',
#        'Appropriate', 'Better', 'Discomfort', 'Discomfort', 'Bored',
#        'Discomfort', 'Discomfort', 'Bored', 'Better', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Anxiety', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Bored', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Better', 'Bored', 'Appropriate', 'Discomfort',
#        'Bored', 'Discomfort', 'Anxiety', 'Bored', 'Discomfort', 'Bored',
#        'Discomfort', 'Bored', 'Bored', 'Bored', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Anxiety', 'Better',
#        'Discomfort', 'Better', 'Discomfort', 'Anxiety', 'Discomfort',
#        'Bored', 'Discomfort', 'Discomfort', 'Bored', 'Bored',
#        'Discomfort', 'Discomfort', 'Appropriate', 'Anxiety', 'Bored',
#        'Discomfort', 'Bored', 'Discomfort', 'Discomfort', 'Bored',
#        'Bored', 'Bored', 'Appropriate', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Bored', 'Anxiety',
#        'Discomfort', 'Anxiety', 'Anxiety', 'Appropriate', 'Bored',
#        'Discomfort', 'Better', 'Discomfort', 'Better', 'Bored', 'Bored',
#        'Discomfort', 'Bored', 'Better', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Appropriate', 'Anxiety', 'Bored',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Anxiety', 'Discomfort',
#        'Discomfort', 'Better', 'Discomfort', 'Bored', 'Discomfort',
#        'Appropriate', 'Bored', 'Bored', 'Discomfort', 'Anxiety', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Anxiety', 'Appropriate', 'Bored',
#        'Discomfort', 'Appropriate', 'Anxiety', 'Bored', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Anxiety', 'Bored', 'Discomfort',
#        'Discomfort', 'Bored', 'Discomfort', 'Bored', 'Discomfort',
#        'Better', 'Discomfort', 'Better', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Appropriate', 'Better', 'Bored', 'Bored',
#        'Discomfort', 'Discomfort', 'Bored', 'Better', 'Bored', 'Bored',
#        'Discomfort', 'Anxiety', 'Anxiety', 'Discomfort', 'Discomfort',
#        'Bored', 'Appropriate', 'Better', 'Discomfort', 'Appropriate',
#        'Better', 'Bored', 'Bored', 'Appropriate', 'Anxiety', 'Bored',
#        'Discomfort', 'Better', 'Discomfort', 'Appropriate', 'Discomfort',
#        'Bored', 'Appropriate', 'Discomfort', 'Discomfort', 'Anxiety',
#        'Bored', 'Discomfort', 'Bored', 'Bored', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Discomfort', 'Better',
#        'Bored', 'Discomfort', 'Bored', 'Discomfort', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Bored', 'Appropriate', 'Bored',
#        'Discomfort', 'Discomfort', 'Bored', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Better', 'Appropriate', 'Appropriate',
#        'Bored', 'Appropriate', 'Better', 'Appropriate', 'Anxiety',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Discomfort', 'Anxiety', 'Discomfort', 'Better',
#        'Bored', 'Discomfort', 'Discomfort', 'Appropriate', 'Bored',
#        'Discomfort', 'Bored', 'Appropriate', 'Discomfort', 'Discomfort',
#        'Bored', 'Better', 'Appropriate', 'Discomfort', 'Bored',
#        'Appropriate', 'Anxiety', 'Appropriate', 'Bored', 'Discomfort',
#        'Discomfort', 'Bored', 'Discomfort', 'Better', 'Appropriate',
#        'Anxiety', 'Bored', 'Anxiety', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Better', 'Discomfort', 'Better', 'Better',
#        'Anxiety', 'Discomfort', 'Discomfort', 'Better', 'Bored', 'Better',
#        'Discomfort', 'Discomfort', 'Appropriate', 'Bored', 'Discomfort',
#        'Better', 'Discomfort', 'Discomfort', 'Bored', 'Discomfort',
#        'Appropriate', 'Bored', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Bored', 'Bored', 'Discomfort', 'Discomfort',
#        'Bored', 'Discomfort', 'Anxiety', 'Bored', 'Discomfort', 'Better',
#        'Bored', 'Discomfort', 'Better', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Bored', 'Appropriate', 'Better',
#        'Discomfort', 'Appropriate', 'Discomfort', 'Better', 'Discomfort',
#        'Discomfort', 'Anxiety', 'Discomfort', 'Better', 'Discomfort',
#        'Bored', 'Better', 'Appropriate', 'Bored', 'Discomfort', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Better', 'Bored',
#        'Discomfort', 'Appropriate', 'Bored', 'Better', 'Anxiety',
#        'Discomfort', 'Bored', 'Better', 'Better', 'Bored', 'Appropriate',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Anxiety', 'Discomfort',
#        'Bored', 'Bored', 'Discomfort', 'Bored', 'Appropriate', 'Anxiety',
#        'Bored', 'Better', 'Better', 'Anxiety', 'Bored', 'Discomfort',
#        'Bored', 'Discomfort', 'Discomfort', 'Bored', 'Discomfort',
#        'Better', 'Appropriate', 'Discomfort', 'Better', 'Bored', 'Better',
#        'Bored', 'Discomfort', 'Appropriate', 'Bored', 'Bored',
#        'Appropriate', 'Better', 'Better', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Better', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Better', 'Better', 'Discomfort',
#        'Discomfort', 'Better', 'Appropriate', 'Anxiety', 'Better',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Appropriate',
#        'Appropriate', 'Appropriate', 'Bored', 'Bored', 'Bored', 'Better',
#        'Anxiety', 'Discomfort', 'Appropriate', 'Anxiety', 'Appropriate',
#        'Better', 'Discomfort', 'Appropriate', 'Better', 'Discomfort',
#        'Anxiety', 'Anxiety', 'Discomfort', 'Better', 'Discomfort',
#        'Anxiety', 'Bored', 'Anxiety', 'Bored', 'Discomfort',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Discomfort',
#        'Appropriate', 'Better', 'Discomfort', 'Discomfort', 'Bored',
#        'Appropriate', 'Discomfort', 'Discomfort', 'Bored', 'Bored',
#        'Discomfort', 'Appropriate', 'Discomfort', 'Appropriate',
#        'Discomfort', 'Anxiety', 'Discomfort', 'Appropriate',
#        'Appropriate', 'Discomfort', 'Appropriate', 'Discomfort',
#        'Discomfort', 'Discomfort', 'Discomfort', 'Appropriate',
#        'Appropriate', 'Bored', 'Bored', 'Bored'], dtype=object)

# %%
y_test
# Out:
# 1265          Bored
# 1048        Anxiety
# 880     Appropriate
# 824     Appropriate
# 370      Discomfort
#            ...
# 878     Appropriate
# 899     Appropriate
# 1084          Bored
# 1287          Bored
# 1241          Bored
# Name: class, Length: 789, dtype: str

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# ## 4. Make Detections with Model

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(1)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # 1. Draw face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp.solutions.face_mesh.FACEMESH_TESSELATION, 
                                 mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                 mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                 )
        
        # 2. Right hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                 )

        # 3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                 )

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Extract Face landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())
            
            # Concate rows
            row = pose_row+face_row
            
#             # Append class name 
#             row.insert(0, class_name)
            
#             # Export to CSV
#             with open('coords.csv', mode='a', newline='') as f:
#                 csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#                 csv_writer.writerow(row) 

            # Make Detections
            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Better [8.69206815e-08 1.46112430e-07 9.99999310e-01 1.70979528e-07
#  2.85880754e-07]
# Better [5.77293303e-08 9.70421839e-08 9.99999542e-01 1.13557942e-07
#  1.89870859e-07]
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Better [9.36755974e-08 1.57467348e-07 9.99999256e-01 1.84266957e-07
#  3.08097567e-07]
# Better [9.36755990e-08 1.40128415e-07 9.99999274e-01 1.84266960e-07
#  3.08097572e-07]
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Better [7.97724459e-08 1.19330824e-07 9.99999382e-01 1.56918411e-07
#  2.62370320e-07]
# Better [2.51271334e-07 4.22383543e-07 9.99998006e-01 4.94269644e-07
#  8.26427467e-07]
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Better [2.98036154e-07 5.00994540e-07 9.99997634e-01 5.86259566e-07
#  9.80236223e-07]
# Better [2.98036170e-07 4.45829401e-07 9.99997690e-01 5.86259599e-07
#  9.80236277e-07]
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Better [2.98036170e-07 4.45829401e-07 9.99997690e-01 5.86259599e-07
#  9.80236277e-07]
# Better [1.57103459e-07 2.35009532e-07 9.99998782e-01 3.09034339e-07
#  5.16710806e-07]
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Better [5.50106607e-08 8.22899109e-08 9.99999573e-01 1.08605606e-07
#  1.80929198e-07]
# Discomfort [1.63909883e-08 2.45191196e-08 1.79589738e-01 3.23601498e-08
#  8.20410189e-01]
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Discomfort [1.63910554e-08 2.45192199e-08 1.79586381e-01 3.23602822e-08
#  8.20413545e-01]
# Discomfort [1.58101998e-08 2.36503238e-08 2.08659665e-01 3.12135196e-08
#  7.91340265e-01]
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Discomfort [1.63138950e-08 2.44037965e-08 1.83448451e-01 3.22079473e-08
#  8.16551476e-01]
# Discomfort [1.61218689e-08 2.41165465e-08 1.93059843e-01 3.18288368e-08
#  8.06940085e-01]
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Discomfort [1

# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Bored [1.10842360e-05 1.65808006e-05 1.09355208e-05 9.99924944e-01
#  3.64558779e-05]
# Bored [1.30650876e-05 1.95439371e-05 1.28897957e-05 9.99911530e-01
#  4.29708676e-05]
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Bored [2.97671952e-04 4.45284570e-04 2.93678141e-04 9.97984327e-01
#  9.79038367e-04]
# Bored [3.49887165e-04 5.23392798e-04 3.45192792e-04 9.97630754e-01
#  1.15077338e-03]
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Bored [3.29277514e-01 1.98550254e-04 1.30771228e-04 6.69994905e-01
#  3.98259535e-04]
# Bored [2.03589412e-01 1.22761888e-04 8.08547084e-05 7.95960731e-01
#  2.46240393e-04]
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Pinmanee\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Bored [2.94985082e-01 1.77872343e-04 1.17152128e-04 7.04363111e-01
#  3.56783006e-04]
# Bored [1.29100090e-01 7.78457520e-05 5.12715768e-05 8.70614646e-01
#  1.56145925e-04]

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# โหลดโมเดลที่เซฟไว้
import pickle
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# ดึงค่า importance
importances = model.named_steps['randomforestclassifier'].feature_importances_

# สร้างชื่อ feature จาก dataset
df = pd.read_csv('coords.csv')
X = df.drop('class', axis=1)

# เรียงลำดับจากมากไปน้อย
indices = np.argsort(importances)[::-1]

# เลือกแค่ 20 อันดับแรก (เพราะ feature เยอะมาก)
top_n = 20
top_features = X.columns[indices][:top_n]
top_importances = importances[indices][:top_n]

# Plot (ห้ามใช้ seaborn และไม่กำหนดสีเอง)
plt.figure()
plt.bar(range(top_n), top_importances)
plt.xticks(range(top_n), top_features, rotation=90)
plt.title("Top 20 Feature Importances - Random Forest")
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# Load dataset
df = pd.read_csv('coords.csv')
X = df.drop('class', axis=1)
y = df['class']

# Train/Test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, random_state=1234, stratify=y
)

# Create pipelines
pipelines = {
    'Logistic Regression': make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000)),
    'Ridge Classifier': make_pipeline(StandardScaler(), RidgeClassifier()),
    'Random Forest': make_pipeline(StandardScaler(), RandomForestClassifier()),
    'Gradient Boosting': make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# Train & collect accuracy
accuracies = {}

for name, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracies[name] = accuracy_score(y_test, y_pred)

# Plot accuracy
plt.figure()
plt.bar(accuracies.keys(), accuracies.values())
plt.title("Model Accuracy Comparison")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# ใช้โมเดล Random Forest
rf_model = pipelines['Random Forest']
rf_pred = rf_model.predict(X_test)

cm = confusion_matrix(y_test, rf_pred)
labels = np.unique(y)

plt.figure()
plt.imshow(cm)
plt.title("Confusion Matrix - Random Forest")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks(range(len(labels)), labels, rotation=45)
plt.yticks(range(len(labels)), labels)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv('coords.csv')
X = df.drop('class', axis=1)
y = df['class']

# Scale data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Reduce to 2D
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Plot
plt.figure()

for label in y.unique():
    indices = y == label
    plt.scatter(X_pca[indices, 0], X_pca[indices, 1])

plt.title("PCA Projection of Body Language Classes")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np

rf = RandomForestClassifier()
rf.fit(X, y)

importances = rf.feature_importances_
indices = np.argsort(importances)[-20:]  # top 20 features

plt.figure()
plt.barh(range(len(indices)), importances[indices])
plt.yticks(range(len(indices)), X.columns[indices])
plt.title("Top 20 Feature Importances")
plt.show()
